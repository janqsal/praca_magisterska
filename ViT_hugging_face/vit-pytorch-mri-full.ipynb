# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms, datasets
from torch.utils.data import DataLoader, random_split
from transformers import ViTFeatureExtractor, ViTForImageClassification
from sklearn.metrics import classification_report , confusion_matrix
import itertools
import matplotlib.pyplot as plt
import torchvision.transforms.functional as TF
from utils import *
from grad_cam import *
import io
from PIL import Image as PILImage
import random

# %%
def apply_train_transforms(image):
    train_transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    return train_transform(image)

# %%
def apply_test_valid_transforms(image):
    val_test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
    ])
    return val_test_transform(image)

# %%
def train_collate_fn(batch):
    transformed_images = []
    labels = []
    for image, label in batch:
        transformed_image = apply_train_transforms(image)
        transformed_images.append(transformed_image)
        labels.append(label)
    return torch.stack(transformed_images), torch.tensor(labels)

# %%
def test_valid_collate_fn(batch):
    transformed_images = []
    labels = []
    for image, label in batch:
        transformed_image = apply_test_valid_transforms(image)
        transformed_images.append(transformed_image)
        labels.append(label)
    return torch.stack(transformed_images), torch.tensor(labels)

# %%
data_dir = "C:/Users/Jan/SGH/magisterka/dane/brain_tumor_mri_cropped"

# %% [markdown]
# ### Transformacje dla poszczególnych zbiorów

# %%
ds = datasets.ImageFolder(data_dir)

# %%
class_names = ds.classes
class_names
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
custom_labels = {0: 'glioma', 1: 'meningioma', 2: 'notumor', 3: 'pituitary'}

# %%
train_size = int(0.8 * len(ds))
valid_size = int(0.1 * len(ds))
test_size = len(ds) - train_size - valid_size

train_dataset, valid_dataset, test_dataset = random_split(ds, [train_size, valid_size, test_size])

# %%
batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=train_collate_fn)
valid_loader = DataLoader(valid_dataset, batch_size=batch_size, shuffle=False, collate_fn=test_valid_collate_fn)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, collate_fn=test_valid_collate_fn)

# %% [markdown]
# ### Ładowanie pre-wytrenowanego modelu

# %%
# Load the pre-trained ViT model
model_name = "google/vit-base-patch16-224-in21k"
feature_extractor = ViTFeatureExtractor(model_name)
model = ViTForImageClassification.from_pretrained(model_name, num_labels=len(ds.classes))
# Out:
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# ### Definiowanie funkcji straty oraz optymizer

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.AdamW(model.parameters(), lr=0.0001)

scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001, total_steps=len(train_loader) * 20)

# %%
num_epochs = 50

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
# Out:
# ViTForImageClassification(
#   (vit): ViTModel(
#     (embeddings): ViTEmbeddings(
#       (patch_embeddings): ViTPatchEmbeddings(
#         (projection): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       )
#       (dropout): Dropout(p=0.0, inplace=False)
#     )
#     (encoder): ViTEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x ViTLayer(
#           (attention): ViTAttention(
#             (attention): ViTSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#             (output): ViTSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.0, inplace=False)
#             )
#           )
#           (intermediate): ViTIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): ViTOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (dropout): Dropout(p=0.0, inplace=False)
#           )
#           (layernorm_before): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (layernorm_after): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         )
#       )
#     )
#     (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   )
#   (classifier): Linear(in_features=768, out_features=4, bias=True)
# )

# %%
model, model_history = train_and_validate(model, train_loader, valid_loader, criterion, optimizer, scheduler, num_epochs, device, "C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/", "vit-pytorch-mri-full-best-model.pth")
# Out:
# Najlepszy model został zapisany do C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/vit-pytorch-mri-full-best-model.pth
# Epoch [1/50] Train Loss: 0.5818, Train Accuracy: 81.88% Val Loss: 0.2370, Val Accuracy: 94.30% Czas trwania epoki: 69.45s
# Najlepszy model został zapisany do C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/vit-pytorch-mri-full-best-model.pth
# Epoch [2/50] Train Loss: 0.2666, Train Accuracy: 91.33% Val Loss: 0.1555, Val Accuracy: 96.44% Czas trwania epoki: 68.76s
# Epoch [3/50] Train Loss: 0.2085, Train Accuracy: 93.56% Val Loss: 0.1389, Val Accuracy: 95.58% Czas trwania epoki: 68.58s
# Najlepszy model został zapisany do C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/vit-pytorch-mri-full-best-model.pth
# Epoch [4/50] Train Loss: 0.1661, Train Accuracy: 94.64% Val Loss: 0.0831, Val Accuracy: 97.58% Czas trwania epoki: 68.87s
# Najlepszy model został zapisany do C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/vit-pytorch-mri-full-best-model.pth
# Epoch [5/50] Train Loss: 0.1488, Train Accuracy: 95.19% Val Loss: 0.0781, Val Accuracy: 97.72% Czas trwania epoki: 68.70s
# Epoch [6/50] Train Loss: 0.1368, Train Accuracy: 95.27% Val Loss: 0.0868, Val Accuracy: 97.01% Czas trwania epoki: 68.38s
# Najlepszy model został zapisany do C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/vit-pytorch-mri-full-best-model.pth
# Epoch [7/50] Train Loss: 0.1235, Train Accuracy: 95.96% Val Loss: 0.0580, Val Accuracy: 98.72% Czas trwania epoki: 68.52s
# Epoch [8/50] Train Loss: 0.1206, Train Accuracy: 95.98% Val Loss: 0.0714, Val Accuracy: 98.01% Czas trwania epoki: 68.29s
# Epoch [9/50] Train Loss: 0.1106, Train Accuracy: 96.23% Val Loss: 0.0490, Val Accuracy: 98.72% Czas trwania epoki: 68.25s
# Epoch [10/50] Train Loss: 0.0985, Train Accuracy: 96.67% Val Loss: 0.0518, Val Accuracy: 98.58% Czas trwania epoki: 68.38s
# Epoch [11/50] Train Loss: 0.1029, Train Accuracy: 96.37% Val Loss: 0.0508, Val Accuracy: 98.15% Czas trwania epoki: 68.46s
# Najlepszy model został zapisany do C:/Users/Jan/SGH/magisterka/repo/praca_magisterska/ViT_hugging_face/vit-pytorch-mri-full-best-model.pth
# Epoch
# Epoch [35/50] Train Loss: 0.0496, Train Accuracy: 98.31% Val Loss: 0.0255, Val Accuracy: 98.72% Czas trwania epoki: 68.44s
# Epoch [36/50] Train Loss: 0.0636, Train Accuracy: 97.97% Val Loss: 0.0397, Val Accuracy: 98.58% Czas trwania epoki: 68.57s
# Epoch [37/50] Train Loss: 0.0461, Train Accuracy: 98.27% Val Loss: 0.0299, Val Accuracy: 99.15% Czas trwania epoki: 68.53s
# Epoch [38/50] Train Loss: 0.0576, Train Accuracy: 97.86% Val Loss: 0.0541, Val Accuracy: 98.15% Czas trwania epoki: 68.48s
# Epoch [39/50] Train Loss: 0.0625, Train Accuracy: 97.72% Val Loss: 0.0259, Val Accuracy: 99.00% Czas trwania epoki: 68.34s
# Epoch [40/50] Train Loss: 0.0510, Train Accuracy: 98.17% Val Loss: 0.0351, Val Accuracy: 99.00% Czas trwania epoki: 68.35s
# Epoch [41/50] Train Loss: 0.0557, Train Accuracy: 97.97% Val Loss: 0.0330, Val Accuracy: 99.00% Czas trwania epoki: 68.53s
# Epoch [42/50] Train Loss: 0.0546, Train Accuracy: 98.11% Val Loss: 0.0350, Val Accuracy: 99.00% Czas trwania epoki: 68.39s
# Epoch [43/50] Train Loss: 0.0440, Train Accuracy: 98.26% Val Loss: 0.0336, Val Accuracy: 98.72% Czas trwania epoki: 68.44s
# Epoch [44/50] Train Loss: 0.0568, Train Accuracy: 97.74% Val Loss: 0.0470, Val Accuracy: 98.72% Czas trwania epoki: 68.54s
# Epoch [45/50] Train Loss: 0.0514, Train Accuracy: 98.13% Val Loss: 0.0437, Val Accuracy: 98.72% Czas trwania epoki: 68.39s
# Epoch [46/50] Train Loss: 0.0573, Train Accuracy: 97.85% Val Loss: 0.0282, Val Accuracy: 99.43% Czas trwania epoki: 68.54s
# Epoch [47/50] Train Loss: 0.0479, Train Accuracy: 98.47% Val Loss: 0.0819, Val Accuracy: 98.15% Czas trwania epoki: 68.43s
# Epoch [48/50] Train Loss: 0.0493, Train Accuracy: 98.43% Val Loss: 0.0494, Val Accuracy: 98.86% Czas trwania epoki: 69.21s
# Epoch [49/50] Train Loss: 0.0524, Train Accuracy: 98.17% Val Loss: 0.0474, Val Accuracy: 98.72% Czas trwania epoki: 68.47s
# Epoch [50/50] Train Loss: 0.0556, Train Accuracy: 97.95% Val Loss: 0.0389, Val Accuracy: 99.00% Czas trwania epoki: 68.54s
# Całkowity czas treningu: 3424.88s

# %%
show_loss_accuracy_plots(model_history)

# %% [markdown]
# ### Testowanie modelu

# %%
model.eval()
test_correct = 0
test_total = 0
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = model(inputs)
        _, predicted = torch.max(outputs.logits, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

test_accuracy = 100 * test_correct / test_total
print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Test Accuracy: 98.86%

# %%
evaluate_model(model, test_loader, device)
# Out:
#               precision    recall  f1-score   support
#
#       glioma       1.00      0.99      0.99       170
#   meningioma       0.98      0.99      0.98       159
#      notumor       1.00      1.00      1.00       204
#    pituitary       0.98      0.98      0.98       170
#
#     accuracy                           0.99       703
#    macro avg       0.99      0.99      0.99       703
# weighted avg       0.99      0.99      0.99       703

# %%
test_predictions, test_labels = get_predictions_and_labels(model, test_loader, device)

# %%
cm_test = confusion_matrix(test_labels, test_predictions)

# %%
plot_confusion_matrix_percent(cm_test, class_names, 'Macierz pomyłek dla zbioru testowego (%)')

# %%
display_images_with_gradcam(model=model, dataset = train_dataset, reshape_transform = reshape_transform_vit_huggingface, custom_labels = custom_labels, num_classes=len(class_names))
# Out:
# Label: glioma
# Label: meningioma
# Label: notumor
# Label: pituitary
